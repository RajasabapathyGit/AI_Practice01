# %% [markdown]
# <a href="https://colab.research.google.com/github/RajasabapathyGit/AI_Practice01/blob/main/00_Base_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==================================================
#  1.           MOUNT GOOGLE DRIVE
#  =================================================
from google.colab import drive
import os

drive.mount('/content/drive')

# SET THE PROJECT PATH
project_path = "/content/drive/My Drive/CLA_Colab_Projects"

if os.path.exists(project_path):
  os.chdir(project_path)
  print(f"Successfully connected! Current Directory: {os.getcwd()}")
else:
  print(f"Paht not found. Check the folder name in Google Drive")


# ===================================================
# 2.      IMPORT CORE AI LIBRARIES
# ===================================================

#Import Pandas for Data manupulations
import pandas as pd

# Import numpy for mathematecial operations
import numpy as ny

# Import matplotlib pyplot for plotting graphs
import matplotlib.pyplot as plt

#import seabon for butification and data visualization
import seaborn as sns

#import tensorflow for deep learning from tensorflow import keras
import tensorflow as tf



#  =================================================
# 3.    CHECHK FOR CPU (GRAPHICS CARD)
#  =================================================

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print('Running on : CPU (Slow for AI)')
else:
  print(f'Running on : GPU (Fast for AI! Device: {device_name})')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Successfully connected! Current Directory: /content/drive/My Drive/CLA_Colab_Projects
# Running on : GPU (Fast for AI! Device: /device:GPU:0)
